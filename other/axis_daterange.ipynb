# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(24*60*100).reshape(100, 24*60 ), 
                  index = pd.date_range('2018-01-01',freq='D',periods= 100) )

df.head()
# Out:
#                 0         1         2         3         4         5     \
# 2018-01-01  0.125607  0.992128 -0.906725  0.979135 -2.012252 -1.212443
# 2018-01-02 -0.995052 -0.592759  0.192456  0.103545  0.793595 -0.149626
# 2018-01-03  0.687922 -0.551504  1.266003 -1.505763  0.920894  0.702004
# 2018-01-04  1.925678  2.130832  0.261687 -0.131717  0.374877 -1.481614
# 2018-01-05  1.495552 -0.531536 -0.537814 -0.384830 -2.051748 -1.759903
#
#                 6         7         8         9       ...         1430  \
# 2018-01-01  1.388961 -1.135493  1.682030  1.009092    ...    -0.023907
# 2018-01-02  0.088078 -1.103586 -0.240670 -0.710753    ...     0.273939
# 2018-01-03  2.182571 -1.470693  0.793094 -0.528629    ...    -0.230725
# 2018-01-04  0.137451 -1.842835  0.525901  0.655197    ...    -0.234652
# 2018-01-05  0.906823  0.314579  0.174686 -0.526724    ...     1.236564
#
#                 1431      1432      1433      1434      1435      1436  \
# ...

# %%
df['max'] = df.apply(lambda row: max(row), axis=1)

df['min_sn'] = df.apply(lambda row: row.idxmax() , axis=1)

df[['max', 'min_sn']].head()
# Out:
#                  max  min_sn
# 2018-01-01  3.504977     806
# 2018-01-02  3.142863     135
# 2018-01-03  3.409892     777
# 2018-01-04  3.380571     219
# 2018-01-05  3.254219    1151
