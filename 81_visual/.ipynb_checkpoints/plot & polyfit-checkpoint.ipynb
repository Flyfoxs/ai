# %% [markdown]
# ## 一个Plot画出2条直线

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = range(0, 10)
plt.plot(x, x)

y = range(4, 10)
plt.plot(y, list(map(lambda val: val*2, y ) ) )

# %% [markdown]
# ## 多项式自动拟合

# %%
x = list(np.arange(0,4,0.4))

y = list(map(lambda val: val**3*3 + np.random.random()*20 , x) )

plt.scatter(x, y)

w = np.polyfit (x, y, 4)

fn = np.poly1d(w)

print(w)
print(fn)

plt.plot(x, fn(x))
# Out:
# [ -1.5835779   12.85935759 -19.79450431  15.13892494   7.13675472]
#         4         3         2
# -1.584 x + 12.86 x - 19.79 x + 15.14 x + 7.137
